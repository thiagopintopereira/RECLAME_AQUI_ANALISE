# %% [markdown]
# # Exercícios
#
# Utilize os arquivos do **RECLAME AQUI** e crie um dashboard com algumas caracteristicas.
#
# Empresas:
# - Hapvida
# - Nagem
# - Ibyte
#
# O painel deve conter tais informações:
#
# 1. Série temporal do número de reclamações.
#
# 2. Frequência de reclamações por estado.
#
# 3. Frequência de cada tipo de **STATUS**
#
# 4. Distribuição do tamanho do texto (coluna **DESCRIÇÃO**)
#
#
# Alguns botões devem ser implementados no painel para operar filtros dinâmicos. Alguns exemplos::
#
# 1. Seletor da empresa para ser analisada.
#
# 2. Seletor do estado.
#
# 3. Seletor por **STATUS**
#
# 4. Seletor de tamanho do texto
#
# Faça o deploy da aplicação. Dicas:
#
# https://www.youtube.com/watch?v=vw0I8i7QJRk&list=PLRFQn2r6xhgcDMhp9NCWMqDYGfeeYsn5m&index=16&t=252s
#
# https://www.youtube.com/watch?v=HKoOBiAaHGg&t=515s
#
# Exemplo do github
# https://github.com/jlb-gmail/streamlit_teste
#
#
# **OBSERVAÇÃO**
#
# A resposta do exercicio é o link do github e o link da aplicação. Coloque-os abaixo.

# %%
import pandas as pd

# %%
df=pd.read_csv('RECLAMEAQUI_IBYTE.csv')

# %%
df.head(30)
# Out:
#           ID                                               TEMA  \
# 0   21898349                   Quebraram a tela do meu Notebook
# 1   22581481              Solicitação de Cancelamento de Compra
# 2   22579385                Inutilizarão a tela do meu notebook
# 3   21328791            Produto não faz o que vendedor informa!
# 4   22608043                          Ibyte não troca o produto
# 5   22599323                                     Prazo de Envio
# 6   20766889  IBYTE não quer restituir meu dinheiro, produto...
# 7   22662001                        [Editado pelo Reclame Aqui]
# 8   22644003  Previsão de Entrega Alta Demais Com produto na...
# 9   21975589                                 Funcionário Sombra
# 10  20801745    COMPREI UM TV LG DE 43 E VEIO COM TELA TRINCADA
# 11  20806507                produto imcompleto e mal atedimento
# 12  20811925                             Pelicula aplica errada
# 13  22052185                                PROPAGANDA ENGANOSA
# 14  20933811                                          DEVOLUÇAO
# 15  20934113                                DEVOLUÇÃO SEM PRAZO
# 16  20958863  FUI ENGANADO COM A COMPRA DO K8 LG NÃO COMPREM...
# 17  20963255    Mp4 Player - Goldentec Não presta!! Muito Ruim!
# 18  20966641                                 Problema na compra
# 19  20991231                                 Problema no mouse.
# 20  20994859                                 TABLET COM DEFEITO
# 21  21007089              celular Motorola - defeito recorrente
# 22  21018933                                Problema na bateria
# 23  21092484                           O pós venda que se dane
# 24  21165165  APÓS AVALIAÇÃO TÉCNICA, MUDANÇA DE VOLTAGEM SE...
# 25  21182409                          Pior garantia que existe.
# 26  21192659                           Descaso com o consumidor
# 27  21227327                                 Tablet nao carrega
# 28  21241875                               Loja nao faz a troca
# 29  21261239                              Descaso com o cliente
#
#                      LOCAL      TEMPO  \
# 0         Hidrolândia - CE 2016-02-11
# 1               Araxá - MG 2016-03-12
# 2           Fortaleza - CE 2016-03-12
# 3           Fortaleza - CE 2016-04-10
# 4           Fortaleza - CE 2016-05-12
# 5      Belo Horizonte - MG 2016-05-12
# 6           Fortaleza - CE 2016-06-09
# 7           Fortaleza - CE 2016-06-12
# 8              Osasco - SP 2016-06-12
# 9   Juazeiro do Norte - CE 2016-07-11
# 10          Maracanaú - CE 2016-08-09
# 11          Fortaleza - CE 2016-08-09
# 12          Fortaleza - CE 2016-08-09
# 13            Aracati - CE 2016-09-11
# 14          Aracoiaba - CE 2016-09-14
# 15          Aracoiaba - CE 2016-09-14
# 16        Ceará-Mirim - RN 2016-09-15
# 17          Fortaleza - CE 2016-09-15
# 18          Fortaleza - CE 2016-09-16
# 19          Fortaleza - CE 2016-09-17
# 20          Fortaleza - CE 2016-09-17
# 21          Fortaleza - CE 2016-09-19
# 22          Fortaleza - CE 2016-09-19
# 23          Fortaleza - CE 2016-09-22
# 24          Fortaleza - CE 2016-09-26
# 25          Fortaleza - CE 2016-09-27
# 26             Sobral - CE 2016-09-27
# 27          Fortaleza - CE 2016-09-29
# 28          Fortaleza - CE 2016-09-29
# 29          Fortaleza - CE 2016-09-30
#
#                                             CATEGORIA         STATUS  \
# 0                   Ibyte - Loja Física<->Informática      Resolvido
# 1   Não consigo fazer operação por telefone<->Cana...     Em réplica
# 2   Problemas na Loja<->Ibyte - Loja Física<->Prod...     Respondida
# 3   Ibyte - Loja Física<->Impressoras<->Produto er...     Em réplica
# 4   Smartphone<->Celulares e Smartphones<->Blackfr...     Respondida
# 5   Acessórios para Celulares, Tablets e Computado...     Em réplica
# 6   Outros<->Ibyte - Loja Física<->Eletroeletrônic...      Resolvido
# 7   Acessórios para Celulares, Tablets e Computado...     Em réplica
# 8   Ibyte - Loja Física<->Atraso na entrega<->Info...      Resolvido
# 9   Comportamento do profissional<->Ibyte - Loja F...  Não resolvido
# 10  Tela trincada<->Ibyte - Loja Física<->TV<->Ele...     Respondida
# 11  Acessórios para Celulares, Tablets e Computado...      Resolvido
# 12  Ibyte - Loja Física<->Celulares e Smartphones<...      Resolvido
# 13  Ibyte - Loja Física<->Celulares e Smartphones<...     Respondida
# 14  Canais de Atendimento<->Demora no reparo<->Iby...      Resolvido
# 15  Aparelhos de som<->Ibyte - Loja Física<->Eletr...      Resolvido
# 16  Ibyte - Loja Física<->Celulares e Smartphones<...  Não resolvido
# 17  Outros<->Não liga<->Ibyte - Loja Física<->Elet...      Resolvido
# 18  Problemas na Loja<->Ibyte - Loja Física<->Outr...      Resolvido
# 19  Acessórios para Celulares, Tablets e Computado...      Resolvido
# 20  Outros<->Problemas com bateria<->Ibyte - Loja ...      Resolvido
# 21  Ibyte - Loja Física<->Celulares e Smartphones<...      Resolvido
# 22  Acessórios para Celulares, Tablets e Computado...      Resolvido
# 23                                Ibyte - Loja Física      Resolvido
# 24  Produto com defeito<->Componentes, peças e ace...     Respondida
# 25  Ibyte - Loja Física<->Funcionários despreparad...  Não resolvido
# 26  Produto com defeito<->Ibyte - Loja Física<->TV...     Respondida
# 27  Acessórios para Celulares, Tablets e Computado...      Resolvido
# 28  Outros<->Mau Atendimento<->Ibyte - Loja Física...      Resolvido
# 29  Notebooks<->Ibyte - Loja Física<->Informática<...      Resolvido
#
#                                             DESCRICAO  \
# 0   Em 05/10/2016 deixei meu Notebook para consert...
# 1   Prezados, efetuei uma compra no site www.ameri...
# 2   Decidi conserta meu notebook que parou de inic...
# 3   Venho através desde canal de reclamação expor ...
# 4   Comprei um celular na black Friday e com 4 dia...
# 5   Prezados,Comprei um relógio garmin para dar de...
# 6   Dia 27/08/16 comprei um tablet GOLDENTEC 8GB 7...
# 7   A exatamente 3 anos, adquiri um HD Externo Por...
# 8   Comprei uma Multifuncional cujo pagamento do b...
# 9   Não existe algo mais constrangedor do que um f...
# 10  NO DIA 05/09/2016 SAI PARA COMPRAR UM TV SAMSU...
# 11  Olá,Comprei um teclado e mouse na Ibyte do Igu...
# 12  Boa tarde efetuei a compra de celular da marca...
# 13  No dia 06/11/16 estive na Ibyte da Loja Parang...
# 14  COMPRAMOS UMA CAIXA ACUSTICA PHILCO 1200 RMS A...
# 15  MINHA ESPOSA E EU COMPRAMOS UMA CAIXA DE SOM D...
# 16  Boa TardaNo ultimo dia 05 de agosto fui a uma ...
# 17  Ganhei um mp4 player da marca Goldentec fabric...
# 18  Estou tentando finalizar a compra e sempre apa...
# 19  Olá, boa tarde!Realizei a compra de um mouse R...
# 20  COMPREI UM TABLET GOLDENTEC MODELO DCEM 62 EM ...
# 21  Oi Ibyte.Eu comprei um celular Motorola na loj...
# 22  Comprei uma bateria Goldentec de vocês e antes...
# 23  Comprei uma caixa Bluetooth da goldentec, 20w,...
# 24  LAMENTÁVEL O OCORRIDO NA LOJA IBYTE DO NORTE S...
# 25  Há um tempo atrás, comprei meu notebook na loj...
# 26  Eu Ivete Aragao sou deficiente física tenho um...
# 27  O tablet de voces sao muito ruins. Eu comprei ...
# 28  Bem, estou decepicionado com a Ibyte. Sempre c...
# 29  Eu nao consigo atendimento pelo telefone para ...
#
#                                                   URL   ANO  MES  DIA  \
# 0   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    2   11
# 1   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    3   12
# 2   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    3   12
# 3   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    4   10
# 4   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    5   12
# 5   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    5   12
# 6   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    6    9
# 7   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    6   12
# 8   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    6   12
# 9   https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    7   11
# 10  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    8    9
# 11  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    8    9
# 12  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    8    9
# 13  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   11
# 14  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   14
# 15  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   14
# 16  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   15
# 17  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   15
# 18  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   16
# 19  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   17
# 20  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   17
# 21  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   19
# 22  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   19
# 23  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   22
# 24  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   26
# 25  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   27
# 26  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   27
# 27  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   29
# 28  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   29
# 29  https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    9   30
#
#     DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS
# 0           42              6              3          1      1
# 1           72             10              5          1      2
# 2           72             10              5          1      2
# 3          101             14              6          2      1
# 4          133             19              3          2      2
# 5          133             19              3          2      2
# 6          161             23              3          2      1
# 7          164             23              6          2      2
# 8          164             23              6          2      2
# 9          193             28              0          3      1
# 10         222             32              1          3      3
# 11         222             32              1          3      3
# 12         222             32              1          3      3
# 13         255             36              6          3      1
# 14         258             37              2          3      2
# 15         258             37              2          3      2
# 16         259             37              3          3      2
# 17         259             37              3          3      2
# 18         260             37              4          3      1
# 19         261             37              5          3      2
# 20         261             37              5          3      2
# 21         263             38              0          3      2
# 22         263             38              0          3      2
# 23         266             38              3          3      1
# 24         270             39              0          3      1
# 25         271             39              1          3      2
# 26         271             39              1          3      2
# 27         273             39              3          3      2
# 28         273             39              3          3      2
# 29         274             39              4          3      3

# %%
df['TEMPO']=pd.to_datetime(df['TEMPO'])

# %%
df.groupby('TEMPO').nunique()['ID'].plot()
# Out:
# <AxesSubplot:xlabel='TEMPO'>

# %%
df.STATUS.value_counts()
# Out:
# Resolvido         430
# Respondida        339
# Em réplica        124
# Não resolvido     103
# Não respondida      4
# Name: STATUS, dtype: int64

# %%
df['LOCAL'].iloc[0]
# Out:
# 'Hidrolândia - CE'

# %%
df['LOCAL'].iloc[0][-2:]
# Out:
# 'CE'

# %%
df['LOCAL'].iloc[0].split('-')[1].strip()
# Out:
# 'CE'

# %%
estado_lista=[]
for i in range(len(df)):
    estado_lista.append(df['LOCAL'].iloc[i].split('-',2)[1].strip())

# %%
estado_lista
# Out:
# ['CE',
#  'MG',
#  'CE',
#  'CE',
#  'CE',
#  'MG',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'Mirim',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'PI',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'PR',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MG',
#  'CE',
#  'PA',
#  'MG',
#  'CE',
#  'CE',
#  'GO',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'PI',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'RN',
#  'SP',
#  'CE',
#  'CE',
#  'PR',
#  'GO',
#  'SP',
#  'CE',
#  'MT',
#  'RS',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'RS',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'MA',
#  'MG',
#  'RJ',
#  'MG',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'MA',
#  'MA',
#  'PA',
#  'CE',
#  'SP',
#  'AP',
#  'CE',
#  'PE',
#  'CE',
#  'PI',
#  'CE',
#  'MA',
#  'RJ',
#  'PI',
#  'CE',
#  'RJ',
#  'PI',
#  'PI',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'PR',
#  'PI',
#  'PI',
#  'MA',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'RN',
#  'RJ',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'MG',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RJ',
#  'SP',
#  'PE',
#  'PB',
#  'BA',
#  'SP',
#  'RN',
#  'PE',
#  'PE',
#  'PB',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'MA',
#  'CE',
#  'CE',
#  'PE',
#  'RJ',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'MA',
#  'PB',
#  'Mirim',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'BA',
#  'PB',
#  'CE',
#  'SP',
#  'MA',
#  'SP',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RJ',
#  'CE',
#  'RN',
#  'CE',
#  'SP',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'DF',
#  'CE',
#  'naoconsta',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'PB',
#  'MA',
#  'CE',
#  'PA',
#  '',
#  'CE',
#  'MA',
#  'PI',
#  'SE',
#  'PE',
#  'CE',
#  'RJ',
#  'SP',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'RN',
#  'MA',
#  'CE',
#  'CE',
#  'PR',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'CE',
#  'GO',
#  'CE',
#  'RJ',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'RS',
#  'PB',
#  'CE',
#  'CE',
#  'MA',
#  'P',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'PE',
#  'RN',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'RN',
#  'PI',
#  'SP',
#  'CE',
#  'CE',
#  'MG',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'DF',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'PE',
#  'CE',
#  'CE',
#  'PE',
#  'C',
#  'CE',
#  'CE',
#  'RN',
#  'PE',
#  'MA',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'C',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'MA',
#  'PE',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'RN',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'PE',
#  'PE',
#  'PA',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'PA',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'PE',
#  'PE',
#  'CE',
#  'PA',
#  'CE',
#  'MA',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PB',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'PA',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'RN',
#  'RN',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'SP',
#  'PI',
#  'CE',
#  'AM',
#  'CE',
#  'CE',
#  'PE',
#  'PA',
#  'PE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'RN',
#  'DF',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'MT',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'PI',
#  'MA',
#  'CE',
#  'SP',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'MA',
#  'PA',
#  'PE',
#  'CE',
#  'DF',
#  'PA',
#  'CE',
#  'CE',
#  'PA',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'AP',
#  'PB',
#  'RN',
#  'CE',
#  'CE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'C',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'PA',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'PI',
#  'MA',
#  'RN',
#  'CE',
#  'BA',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RJ',
#  'PE',
#  'CE',
#  'CE',
#  'RN',
#  'PE',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'RN',
#  'CE',
#  'PA',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'BA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'PA',
#  'MA',
#  'CE',
#  'MA',
#  'PE',
#  'CE',
#  'MA',
#  'RN',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'MA',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'MA',
#  'CE',
#  'DF',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PA',
#  'CE',
#  'PI',
#  'BA',
#  'CE',
#  'PA',
#  'DF',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PB',
#  'PI',
#  'DF',
#  'PA',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PA',
#  'CE',
#  'AM',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'PE',
#  'RN',
#  'CE',
#  'CE',
#  'SP',
#  'PI',
#  'RN',
#  'CE',
#  'RN',
#  'PA',
#  'RN',
#  'MA',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'PE',
#  'MA',
#  'PE',
#  'CE',
#  'CE',
#  'naoconsta',
#  'CE',
#  'MA',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'RN',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PI',
#  'PA',
#  'CE',
#  'C',
#  'CE',
#  'PB',
#  'SP',
#  'PI',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'BA',
#  'CE',
#  'PI',
#  'CE',
#  'CE',
#  'PE',
#  'PA',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PB',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'SP',
#  'PE',
#  'MA',
#  'PE',
#  'CE',
#  'PA',
#  'RN',
#  'CE']

# %%
df['ESTADO']=estado_lista

# %%
df
# Out:
#             ID                                            TEMA  \
# 0     21898349                Quebraram a tela do meu Notebook
# 1     22581481           Solicitação de Cancelamento de Compra
# 2     22579385             Inutilizarão a tela do meu notebook
# 3     21328791         Produto não faz o que vendedor informa!
# 4     22608043                       Ibyte não troca o produto
# ..         ...                                             ...
# 995  148162149                        Me senti humilhado hoje
# 996  148246105               Meu notebook retornou arranhado.
# 997  136408859                     Película com falha no corte
# 998  146670431  Péssimo atendimento de TI na loja ibyte midway
# 999  146654995                        Comprei uma memória dd30
#
#                 LOCAL      TEMPO  \
# 0    Hidrolândia - CE 2016-02-11
# 1          Araxá - MG 2016-03-12
# 2      Fortaleza - CE 2016-03-12
# 3      Fortaleza - CE 2016-04-10
# 4      Fortaleza - CE 2016-05-12
# ..                ...        ...
# 995       Recife - PE 2022-09-08
# 996    Fortaleza - CE 2022-10-08
# 997    Castanhal - PA 2022-11-01
# 998      Mossoró - RN 2022-12-07
# 999    Fortaleza - CE 2022-12-07
#
#                                              CATEGORIA      STATUS  \
# 0                    Ibyte - Loja Física<->Informática   Resolvido
# 1    Não consigo fazer operação por telefone<->Cana...  Em réplica
# 2    Problemas na Loja<->Ibyte - Loja Física<->Prod...  Respondida
# 3    Ibyte - Loja Física<->Impressoras<->Produto er...  Em réplica
# 4    Smartphone<->Celulares e Smartphones<->Blackfr...  Respondida
# ..                                                 ...         ...
# 995  Acessórios para Celulares, Tablets e Computado...   Resolvido
# 996  Notebooks<->Mau Atendimento<->Ibyte - Loja Fís...  Respondida
# 997  Acessórios para Celulares, Tablets e Computado...   Resolvido
# 998  Computadores all in one<->Mau Atendimento<->Ib...   Resolvido
# 999  Mau Atendimento<->Máquina fotográfica<->Foto e...  Respondida
#
#                                              DESCRICAO  \
# 0    Em 05/10/2016 deixei meu Notebook para consert...
# 1    Prezados, efetuei uma compra no site www.ameri...
# 2    Decidi conserta meu notebook que parou de inic...
# 3    Venho através desde canal de reclamação expor ...
# 4    Comprei um celular na black Friday e com 4 dia...
# ..                                                 ...
# 995  Hj me senti Humilhado no Shopping Guararapes P...
# 996  Em Maio deste ano, meu notebook apresentou um ...
# 997  Comprei uma película de gel na iByte para o me...
# 998  na noite de 12/07/2022 comprei um monitor na l...
# 999  Comprei uma memória na loja ibilyte no shoppin...
#
#                                                    URL   ANO  MES  DIA  \
# 0    https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    2   11
# 1    https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    3   12
# 2    https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    3   12
# 3    https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    4   10
# 4    https://www.reclameaqui.com.br//ibyte-loja-fis...  2016    5   12
# ..                                                 ...   ...  ...  ...
# 995  https://www.reclameaqui.com.br//ibyte-loja-fis...  2022    9    8
# 996  https://www.reclameaqui.com.br//ibyte-loja-fis...  2022   10    8
# 997  https://www.reclameaqui.com.br//ibyte-loja-fis...  2022   11    1
# 998  https://www.reclameaqui.com.br//ibyte-loja-fis...  2022   12    7
# 999  https://www.reclameaqui.com.br//ibyte-loja-fis...  2022   12    7
#
#      DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS ESTADO
# 0            42              6              3          1      1     CE
# 1            72             10              5          1      2     MG
# 2            72             10              5          1      2     CE
# 3           101             14              6          2      1     CE
# 4           133             19              3          2      2     CE
# ..          ...            ...            ...        ...    ...    ...
# 995         251             36              3          3      2     PE
# 996         281             40              5          4      1     CE
# 997         305             44              1          4      1     PA
# 998         341             49              2          4      2     RN
# 999         341             49              2          4      2     CE
#
# [1000 rows x 17 columns]

# %%
df[df['ESTADO']=='CE'].groupby('TEMPO').nunique()['ID'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='TEMPO'>

# %%
def count_palavras(texto):
    return len(texto.split())

# %%
df['DESCRICAO'].apply(count_palavras).plot(kind='hist',density=True)
df['DESCRICAO'].apply(count_palavras).plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
